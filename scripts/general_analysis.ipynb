# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_parquet('../data/source/cleaned_source.parquet')
df
# Out:
#                      id symbol                name
# 0               bitcoin    btc             Bitcoin  \
# 1              ethereum    eth            Ethereum
# 2                tether   usdt              Tether
# 3           binancecoin    bnb                 BNB
# 4              usd-coin   usdc            USD Coin
# ..                  ...    ...                 ...
# 495                 gas    gas                 Gas
# 496      gods-unchained   gods      Gods Unchained
# 497               bytom    btm               Bytom
# 498        xcad-network   xcad        XCAD Network
# 499  league-of-kingdoms   loka  League of Kingdoms
#
#                                                  image  current_price
# 0    https://assets.coingecko.com/coins/images/1/la...   26923.000000  \
# 1    https://assets.coingecko.com/coins/images/279/...    1815.960000
# 2    https://assets.coingecko.com/coins/images/325/...       0.999781
# ...

# %%
df.sort_values('current_price', ascending=False)
# Out:
#                                   id    symbol
# 206  bitcoin-avalanche-bridged-btc-b     btc.b  \
# 18                   wrapped-bitcoin      wbtc
# 0                            bitcoin       btc
# 152                        huobi-btc      hbtc
# 166                    yearn-finance       yfi
# ..                               ...       ...
# 452                  a-hunters-dream       caw
# 131                         safemoon  safemoon
# 119                   baby-doge-coin  babydoge
# 479                        richquack     quack
# 435                       arbdoge-ai    aidoge
#
#                                   name
# 206  Bitcoin Avalanche Bridged (BTC.b)  \
# 18                     Wrapped Bitcoin
# 0                              Bitcoin
# 152                          Huobi BTC
# 166                      yearn.finance
# ..                                 ...
# 452                    A Hunters Dream
# 131                     SafeMoon [OLD]
# ...

# %%
df['current_price'].describe()
# Out:
# count    4.980000e+02
# mean     2.863510e+02
# std      2.443921e+03
# min      2.776720e-10
# 25%      6.807450e-02
# 50%      4.160630e-01
# 75%      1.837500e+00
# max      2.695500e+04
# Name: current_price, dtype: float64

# %%
top_half = df.sort_values('current_price', ascending=False).head(int(len(df) / 2))
top_half
# Out:
#                                   id  symbol
# 206  bitcoin-avalanche-bridged-btc-b   btc.b  \
# 18                   wrapped-bitcoin    wbtc
# 0                            bitcoin     btc
# 152                        huobi-btc    hbtc
# 166                    yearn-finance     yfi
# ..                               ...     ...
# 147                            swipe     sxp
# 371                           vibing     vbg
# 470                           pendle  pendle
# 360                           bancor     bnt
# 313                            mobox    mbox
#
#                                   name
# 206  Bitcoin Avalanche Bridged (BTC.b)  \
# 18                     Wrapped Bitcoin
# 0                              Bitcoin
# 152                          Huobi BTC
# 166                      yearn.finance
# ..                                 ...
# 147                                SXP
# 371                             Vibing
# 470                             Pendle
# ...

# %%
top_half[top_half['current_price'] > 2]
# Out:
#                                   id symbol
# 206  bitcoin-avalanche-bridged-btc-b  btc.b  \
# 18                   wrapped-bitcoin   wbtc
# 0                            bitcoin    btc
# 152                        huobi-btc   hbtc
# 166                    yearn-finance    yfi
# ..                               ...    ...
# 259                          radicle    rad
# 163                 ethereum-pow-iou   ethw
# 399                     aura-finance   aura
# 385                     xido-finance   xido
# 118                       btse-token   btse
#
#                                   name
# 206  Bitcoin Avalanche Bridged (BTC.b)  \
# 18                     Wrapped Bitcoin
# 0                              Bitcoin
# 152                          Huobi BTC
# 166                      yearn.finance
# ..                                 ...
# 259                            Radicle
# 163                        EthereumPoW
# 399                       Aura Finance
# ...

# %%
sns.scatterplot(data=top_half, x='current_price', y='market_cap')
# Out:
# <Axes: xlabel='current_price', ylabel='market_cap'>

# %%
sns.boxplot(data=top_half, y='atl_change_percentage')
# Out:
# <Axes: ylabel='atl_change_percentage'>

# %%
sns.kdeplot(data=top_half, x='current_price', y='market_cap')
# Out:
# <Axes: xlabel='current_price', ylabel='market_cap'>

# %%
btw_5k_price = df[(df['current_price'] > 100) & (df['current_price'] < 10000)]
btw_5k_price
# Out:
#                      id   symbol                name
# 1              ethereum      eth            Ethereum  \
# 3           binancecoin      bnb                 BNB
# 7          staked-ether    steth   Lido Staked Ether
# 24               monero      xmr              Monero
# 29         bitcoin-cash      bch        Bitcoin Cash
# 37        quant-network      qnt               Quant
# 69      rocket-pool-eth     reth     Rocket Pool ETH
# 80                maker      mkr               Maker
# 89             pax-gold     paxg            PAX Gold
# 94          tether-gold     xaut         Tether Gold
# 105          frax-ether   frxeth          Frax Ether
# 125              gnosis      gno              Gnosis
# 153   staked-frax-ether  sfrxeth   Staked Frax Ether
# 166       yearn-finance      yfi       yearn.finance
# 175          gains-farm   gfarm2          Gains Farm
# 213               seth2    seth2               sETH2
# 225  wrapped-beacon-eth    wbeth  Wrapped Beacon ETH
# ...

# %%
sns.histplot(data=btw_5k_price, x='current_price', bins=20)
# Out:
# <Axes: xlabel='current_price', ylabel='Count'>

# %%
sns.boxplot(data=btw_5k_price, y='current_price')
# Out:
# <Axes: ylabel='current_price'>

# %%
sns.scatterplot(data=btw_5k_price, x='current_price')
# Out:
# <Axes: xlabel='current_price'>
